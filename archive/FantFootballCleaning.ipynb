# %%
import nfl_data_py as nfl
import pandas as pd

# %%
years = [2018]

# %%
depth_chart = nfl.import_depth_charts([2021])
depth_chart = depth_chart[depth_chart.position == 'QB']
depth_chart
# Out:
#        season  week team season_type position depth_chart_position formation  \
# 24       2021     1  ATL         REG       QB                   QB   Offense
# 54       2021     1  ATL         REG       QB                   QB   Offense
# 78       2021     2  ATL         REG       QB                   QB   Offense
# 101      2021     2  ATL         REG       QB                   QB   Offense
# 111      2021     3  ATL         REG       QB                   QB   Offense
# ...       ...   ...  ...         ...      ...                  ...       ...
# 37404    2021    18  HOU         REG       QB                   QB   Offense
# 37405    2021    18  HOU         REG       QB                   QB   Offense
# 37462    2021    19  HOU         REG       QB                   QB   Offense
# 37463    2021    19  HOU         REG       QB                   QB   Offense
# 37464    2021    19  HOU         REG       QB                   QB   Offense
#
# ...

# %%
picks = nfl.import_draft_picks([2022])
picks
# Out:
#        season  round  pick team gsis_id pfr_player_id        cfb_player_id  \
# 11635    2022      1     1  JAX    None      WalkTr03      travon-walker-1
# 11636    2022      1     2  DET    None      HutcAi00   aidan-hutchinson-1
# 11637    2022      1     3  HOU    None      StinDe00  derek-stingley-jr-1
# 11638    2022      1     4  NYJ    None      GardAh00      ahmad-gardner-1
# 11639    2022      1     5  NYG    None      ThibKa00  kayvon-thibodeaux-1
# ...       ...    ...   ...  ...     ...           ...                  ...
# 11892    2022      7   258  GNB    None      TourSa00       samori-toure-1
# 11893    2022      7   259  KAN    None      JohnNa01     nazeeh-johnson-1
# 11894    2022      7   260  LAC    None      HorvZa00  alexander-horvath-1
# 11895    2022      7   261  LAR    None      ArcuAJ00          aj-arcuri-1
# 11896    2022      7   262  SFO    None      PurdBr00        brock-purdy-1
#
# ...

# %%
ngs_data = nfl.import_ngs_data(stat_type='rushing', years=[2020])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 ngs_data = nfl.import_ngs_data(stat_type='rushing', years=[2020])
#
# File ~/opt/anaconda3/envs/FantFootballV2/lib/python3.9/site-packages/nfl_data_py/__init__.py:665, in import_ngs_data(stat_type, years)
#     663 else:
#     664     url = r'https://github.com/nflverse/nflverse-data/releases/download/nextgen_stats/ngs_{0}_{1}.parquet'
# --> 665     data = pandas.concat([pandas.read_parquet(url.format(x, stat_type), engine='auto') for x in years])
#     667 # return
#     668 return data
#
# File ~/opt/anaconda3/envs/FantFootballV2/lib/python3.9/site-packages/nfl_data_py/__init__.py:665, in <listcomp>(.0)
#     663 else:
#     664     url = r'https://github.com/nflverse/nflverse-data/releases/download/nextgen_stats/ngs_{0}_{1}.parquet'
# ...

# %%
df_pfr = nfl.import_pfr(s_type='pass', years=[2020])
df_pfr

# %%
l = []
for i in range(259):
    l.append(i + 1)
df_draft_val = nfl.import_draft_values(l)
df_draft_val

# %%
qb_ratings = nfl.import_qbr(years=years)
qb_ratings
# Out:
#      season season_type     game_week team_abb  player_id         name_short  \
# 863    2018     Regular  Season Total       KC    3139477         P. Mahomes
# 864    2018     Regular  Season Total       NO       2580           D. Brees
# 865    2018     Regular  Season Total      CHI    3039707        M. Trubisky
# 866    2018     Regular  Season Total      PIT       5536  B. Roethlisberger
# 867    2018     Regular  Season Total      IND      14874            A. Luck
# ..      ...         ...           ...      ...        ...                ...
# 932    2018    Playoffs  Season Total      HOU    3122840          D. Watson
# 933    2018    Playoffs  Season Total      BAL    3916387         L. Jackson
# 934    2018    Playoffs  Season Total      LAR      15153          J. Hekker
# 935    2018    Playoffs  Season Total      PHI    3042429       W. Smallwood
# 936    2018    Playoffs  Season Total       NO    2468609            T. Hill
#
# ...

# %%
player_data = nfl.import_seasonal_data(years=years, s_type='REG')
player_data
# Out:
#       player_id  season season_type  completions  attempts  passing_yards  \
# 0    00-0019596    2018         REG          375       570         4355.0
# 1    00-0020531    2018         REG          364       489         3992.0
# 2    00-0021206    2018         REG           60       110          539.0
# 3    00-0021547    2018         REG            0         0            0.0
# 4    00-0022787    2018         REG            5         7           20.0
# ..          ...     ...         ...          ...       ...            ...
# 607  00-0034855    2018         REG          310       486         3725.0
# 608  00-0034857    2018         REG          169       320         2074.0
# 609  00-0034860    2018         REG            0         0            0.0
# 610  00-0034867    2018         REG            0         0            0.0
# 611  00-0034869    2018         REG          239       414         2865.0
#
#      passing_tds  interceptions  sacks  sack_yards  ...    yac_sh      wopr  \
# ...

# %%
id_data = nfl.import_ids()
id_data
# Out:
#        mfl_id                         sportradar_id  fantasypros_id gsis_id  \
# 0       15691  d7f4a7fe-86b6-44d8-8944-58271f1299b1         23028.0     NaN
# 1       15692  ef7ae1f1-4ebe-4759-bbb3-32bd177ace08         22722.0     NaN
# 2       15693  7d85e9c2-f464-4654-9200-acfcffd7dfaf         23045.0     NaN
# 3       15694  55aefcf9-4dfb-4994-883f-4d537a6f1ddb         23499.0     NaN
# 4       15695                                   NaN             NaN     NaN
# ...       ...                                   ...             ...     ...
# 10910     972                                   NaN             NaN     NaN
# 10911     978                                   NaN             NaN     NaN
# 10912     984                                   NaN             NaN     NaN
# 10913     990                                   NaN             NaN     NaN
# 10914     996                                   NaN             NaN     NaN
#
# ...

# %%
testing = id_data[id_data.gsis_id=='00-0019596']

# %%
testing1 = qb_ratings[qb_ratings.team_abb == 'TB']

# %%
testing
# Out:
#       mfl_id                         sportradar_id  fantasypros_id  \
# 7736    5848  41c44740-d0f6-44ab-8347-3b5d515e5ecf          9603.0
#
#          gsis_id  pff_id  sleeper_id            nfl_id  espn_id  yahoo_id  \
# 7736  00-0019596   698.0       167.0  tombrady/2504211   2330.0    5228.0
#
#       fleaflicker_id  ...   age  draft_year  draft_round  draft_pick  \
# 7736           309.0  ...  44.9      2000.0          6.0        33.0
#
#      draft_ovr twitter_username  height  weight   college  db_season
# 7736     199.0              NaN    76.0   225.0  Michigan       2022
#
# [1 rows x 35 columns]

# %%
testing1
# Out:
#      season season_type     game_week team_abb  player_id      name_short  \
# 870    2018     Regular  Season Total       TB    2969939      J. Winston
# 918    2018     Regular  Season Total       TB       8664  R. Fitzpatrick
#
#      rank  qbr_total  pts_added  qb_plays  ...  exp_sack  penalty  qbr_raw  \
# 870   8.0       66.2       28.6       485  ...         0      5.4     69.7
# 918   NaN       61.0       10.8       310  ...         0      1.0     62.1
#
#      sack  name_first    name_last      name_display  \
# 870 -11.6      Jameis      Winston    Jameis Winston
# 918  -5.0        Ryan  Fitzpatrick  Ryan Fitzpatrick
#
#                                          headshot_href        team qualified
# 870  https://a.espncdn.com/i/headshots/nfl/players/...  Buccaneers      True
# 918  https://a.espncdn.com/i/headshots/nfl/players/...  Buccaneers     False
#
# [2 rows x 23 columns]

# %%
# qb_ratings uses espn_id
# player_data uses gsis_id

# %%
qbr_and_ids = qb_ratings.merge(id_data, left_on='player_id', right_on='espn_id', suffixes=('_left', '_right'))

# %%
qbr_and_ids = qbr_and_ids[qbr_and_ids.season_type == 'Regular']

# %%
qbr_and_ids
# Out:
#     season season_type     game_week team_abb  player_id         name_short  \
# 0     2018     Regular  Season Total       KC    3139477         P. Mahomes
# 2     2018     Regular  Season Total       NO       2580           D. Brees
# 4     2018     Regular  Season Total      CHI    3039707        M. Trubisky
# 6     2018     Regular  Season Total      PIT       5536  B. Roethlisberger
# 7     2018     Regular  Season Total      IND      14874            A. Luck
# 9     2018     Regular  Season Total       NE       2330           T. Brady
# 11    2018     Regular  Season Total      LAC       5529          P. Rivers
# 13    2018     Regular  Season Total       TB    2969939         J. Winston
# 14    2018     Regular  Season Total      ATL      11237            M. Ryan
# 15    2018     Regular  Season Total      LAR    3046779            J. Goff
# 17    2018     Regular  Season Total      SEA      14881          R. Wilson
# ...

# %%
combined_df = qbr_and_ids.merge(player_data, left_on='gsis_id', right_on='player_id', suffixes=('_l', '_r'))

# %%
combined_df
# Out:
#     season_l season_type_l     game_week team_abb  player_id_l  \
# 0       2018       Regular  Season Total       KC      3139477
# 1       2018       Regular  Season Total       NO         2580
# 2       2018       Regular  Season Total      CHI      3039707
# 3       2018       Regular  Season Total      PIT         5536
# 4       2018       Regular  Season Total      IND        14874
# 5       2018       Regular  Season Total       NE         2330
# 6       2018       Regular  Season Total      LAC         5529
# 7       2018       Regular  Season Total       TB      2969939
# 8       2018       Regular  Season Total      ATL        11237
# 9       2018       Regular  Season Total      LAR      3046779
# 10      2018       Regular  Season Total      SEA        14881
# 11      2018       Regular  Season Total      PHI      2573079
# 12      2018       Regular  Season Total      HOU      3122840
# 13      2018       Regular  Season Total      MIN        14880
# ...
